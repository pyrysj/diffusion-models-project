# %% [markdown]
# Goals for this notebook:
#
# VQ-VAE implementation.
#
# Papers we will be using:
# https://arxiv.org/html/2309.11641v2
#
# Keep this in mind: https://docs.pytorch.org/tutorials/intermediate/transformer_building_blocks.html

# %%
# Begin with some imports
import torch
import torch.optim as optim 
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset
import torch.nn.functional as F 
import numpy as np
import matplotlib.pyplot as plt

# %%
class PixelAttention(nn.Module):
    """Class for implementing Residual Pixel attention, as described in 2309.1141
    Arguments:
    TODO: Arguments"""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class ResBlock(nn.Module):
    """Class for Resblocks used in defining the AREN (attentive residual encoder) architecture.
    Arguments:
    TODO: arguments"""
    def __init__(self):
        super().__init__()

class ResidualEncoder(nn.Module):
    """Initialise the residual encoder.
    Arguments:
    r: repeat IdResblock r times
    R: repeat IdResblock r + Conv Resblock R times"""
    def __init__(self, r, R):
        super().__init__(self, ResidualEncoder)
